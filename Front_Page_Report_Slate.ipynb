# %%
from front_page_report import *
import warnings
warnings.filterwarnings("ignore")
from IPython.display import display, Markdown
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# print title
print(display(Markdown("## **FRONT PAGE REPORT: SLATE**")))

# print report
predict_all(slate_front_page())
# Out:
# ## **FRONT PAGE REPORT: SLATE**
# WARNING: Logging before flag parsing goes to stderr.
# W0726 15:22:02.449912 4476106176 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0726 15:22:02.467887 4476106176 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0726 15:22:02.487344 4476106176 deprecation_wrapper.py:119] From /anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# None
# ...
